# %%
import yfinance as yf
import pandas as pd
from google.colab import files

tickers = ['MTUM', 'XLE', 'XLF', 'XLU', 'XLI', 'XLK', 'XLV', 'XLY', 'XLP', 'XLB', 'SMH', 'AIQ']
benchmark         = 'MTUM'
portfolio_tickers = ['XLE', 'XLF', 'XLU', 'XLI', 'XLK', 'XLV', 'XLY', 'XLP', 'XLB', 'SMH', 'AIQ']
raw_data = yf.download(tickers, period='20y', auto_adjust=False, interval='1d')
display(raw_data.tail(2))
raw_data.to_parquet('raw_data.parquet')
files.download('raw_data.parquet')
# Out:
# [*********************100%***********************]  12 of 12 completed
# Price       Adj Close                                                \
# Ticker            AIQ        MTUM         SMH        XLB        XLE
# Date
# 2025-08-12  45.340000  247.860001  300.100006  89.300003  84.660004
# 2025-08-13  45.470001  245.255005  299.209991  90.339996  84.805000
#
# Price                                                                ...  \
# Ticker            XLF         XLI         XLK        XLP        XLU  ...
# Date                                                                 ...
# 2025-08-12  52.459999  151.899994  268.209991  82.629997  86.279999  ...
# 2025-08-13  52.512501  151.110001  267.510010  82.779999  85.864998  ...
#
# Price        Volume                                                           \
# Ticker          SMH      XLB       XLE       XLF      XLI      XLK       XLP
# Date
# 2025-08-12  7592800  6250600  17261300  37510000  9518300  5576900  16449500
# 2025-08-13  5109648  4884866   7420651  22869903  8100017  3670399  10680964
#
# Price
# Ticker           XLU       XLV      XLY
# Date
# 2025-08-12  10378400  17219500  4895700
# 2025-08-13   6319061   9324162  3617824
#
# [2 rows x 72 columns]
